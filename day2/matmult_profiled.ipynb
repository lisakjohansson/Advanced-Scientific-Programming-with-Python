# %%
import random

N = 250

def make_matrices(N):

    # NxN matrix
    X = []
    for _ in range(N):
        X.append([random.randint(0, 100) for _ in range(N)])

    # Nx(N+1) matrix
    Y = []
    for _ in range(N):
        Y.append([random.randint(0, 100) for _ in range(N+1)])

    return X, Y

def matmult(X, Y, N):

    # result is Nx(N+1)
    result = []
    for i in range(N):
        result.append([0] * (N+1))

    # iterate through rows of X
    for i in range(len(X)):

        # iterate through columns of Y
        for j in range(len(Y[0])):

            # iterate through rows of Y
            for k in range(len(Y)):
                result[i][j] += X[i][k] * Y[k][j]

    return result

# %%
X, Y = make_matrices(N)

# %%
# %pip install line_profiler
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext line_profiler

# %%
# Notebook eqvi of kernprof -l -v matmult_profiled.py

# %lprun -f make_matrices make_matrices(N)
# %lprun -f matmult matmult(X, Y, N)
# Out:
# Timer unit: 1e-09 s
#
# Total time: 13.3221 s
# File: /var/folders/dd/h116tb6j6lz7lprvxkylcp8h0000gn/T/ipykernel_76666/4126538760.py
# Function: matmult at line 20
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ...
#     20                                           def matmult(X, Y, N):
#     21
#     22                                               # result is Nx(N+1)
#     23         1          0.0      0.0      0.0      result = []
#     24       251      55000.0    219.1      0.0      for i in range(N):
#     25       250     166000.0    664.0      0.0          result.append([0] * (N+1))
#     26
#     27                                               # iterate through rows of X
#     28       251      58000.0    231.1      0.0      for i in range(len(X)):
#     29
#     30                                                   # iterate through columns of Y
#     31     63000   15552000.0    246.9      0.1          for j in range(len(Y[0])):
#     32
# ...
