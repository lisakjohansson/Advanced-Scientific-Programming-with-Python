# %%
from classroom import Student

me = Student('Lisa', 'Johansson', 'Molecular Life Sciences') 
me.printNameSubject()
# Out:
# Lisa Johansson, Molecular Life Sciences

# %%
from classroom import Teacher

me = Teacher('Lisa', 'Johansson', 'Physical Molecular Biology') 
me.printNameCourse()
# Out:
# Lisa Johansson, Physical Molecular Biology
